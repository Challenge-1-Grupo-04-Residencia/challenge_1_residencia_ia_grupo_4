# %% [markdown]
# # EDA — Camada N0: Cache de Checagens Conhecidas
#
# **Objetivo:** Investigar o formato das alegações checadas e avaliar a viabilidade de busca por similaridade semântica para resposta imediata (regra RN-01).
#
# - **Datasets analisados:** `central-de-fatos` e `factck-br`
# - **Camada correspondente:** N0 (Cache e Fatos Conhecidos)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuracao de visualizacao
sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", None)

# %%
# 1. Carregamento dos dados padronizados
df_central = pd.read_parquet("../datasets/central-de-fatos/padronizado.parquet")
df_factck = pd.read_parquet("../datasets/factck-br/padronizado.parquet")

print("Central de Fatos:", df_central.shape)
print("FACTCK.BR:", df_factck.shape)

# %%
# 2. Primeiras linhas da Central de Fatos
df_central.head(3)
